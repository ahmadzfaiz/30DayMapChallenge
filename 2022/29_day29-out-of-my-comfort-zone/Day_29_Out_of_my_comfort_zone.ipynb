# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
negara = gpd.read_file('data.gpkg')

negara
# Out:
#           featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0    Admin-0 country          1          6                         Fiji
# 1    Admin-0 country          1          3  United Republic of Tanzania
# 2    Admin-0 country          1          7               Western Sahara
# 3    Admin-0 country          1          2                       Canada
# 4    Admin-0 country          1          2     United States of America
# ..               ...        ...        ...                          ...
# 172  Admin-0 country          1          5           Republic of Serbia
# 173  Admin-0 country          1          6                   Montenegro
# 174  Admin-0 country          1          6                       Kosovo
# 175  Admin-0 country          1          5          Trinidad and Tobago
# 176  Admin-0 country          1          3                  South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE TLC  \
# ...

# %%
negara.plot()

plt.show()

# %%
negara.plot(color='red', edgecolor='black')

plt.show()

# %%
negara.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=169)

# %%
label = negara['INCOME_GRP'].unique()

label
# Out:
# array(['4. Lower middle income', '5. Low income', '1. High income: OECD',
#        '3. Upper middle income', '2. High income: nonOECD'], dtype=object)

# %%
negara.plot(figsize=[10,30],
            cmap='jet', 
            edgecolor='black', 
            column='INCOME_GRP',
            legend=True,
            legend_kwds={'loc': 'lower left'})

plt.show()

# %%
negara.plot(figsize=[10,30],
            cmap='jet', 
            edgecolor='black', 
            column='INCOME_GRP',
            legend=True,
            legend_kwds={'loc': 'lower left'})

plt.title('INCOME GRP Map by Country')
plt.xlabel('longitude')
plt.ylabel('latitude')

plt.text(45, -135, 
         '©Ahmad Zaenun Faiz 2022\nCreated with Python using GeoPandas and Matplotlib\nData: Natural Earth 110m Admin 0 Countries', 
         fontsize=8)

plt.show()
